# %% [markdown]
# # Exit Interviews
#
# We got exit interview data from the <a href="https://data.gov.au/dataset/ds-qld-fe96ff30-d157-4a81-851d-215f2a0fe26d/details?q=exit%20survey">Department of Education, Training and Employment (DETE)</a> and the <a href="https://data.gov.au/dataset/ds-qld-89970a3b-182b-41ea-aea2-6f9f17b5907e/details?q=exit%20survey">Technical and Further Education (TAFE) institute</a> in Queensland, Australia.
#
# This some pretty swag shit, ufeelme, so let's get down to it

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

from IPython.display import display
pd.options.display.max_columns = None # display all a dem columns

# %%
dete_survey = pd.read_csv('dete_survey.csv', na_values='Not Stated')
tafe_survey = pd.read_csv('tafe_survey.csv')

# %%
dete_survey.describe(include='all')
# Out:
#                 ID  SeparationType Cease Date  DETE Start Date  \
# count   822.000000             822        788       749.000000
# unique         NaN               9         24              NaN
# top            NaN  Age Retirement       2012              NaN
# freq           NaN             285        344              NaN
# mean    411.693431             NaN        NaN      1994.182911
# std     237.705820             NaN        NaN        13.880503
# min       1.000000             NaN        NaN      1963.000000
# 25%     206.250000             NaN        NaN      1982.000000
# 50%     411.500000             NaN        NaN      1996.000000
# 75%     616.750000             NaN        NaN      2007.000000
# max     823.000000             NaN        NaN      2013.000000
#
#         Role Start Date Position Classification        Region  \
# count        724.000000      817            455           717
# unique              NaN       15              8             8
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             788 non-null object
# DETE Start Date                        749 non-null float64
# Role Start Date                        724 non-null float64
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 717 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
tafe_survey.describe(include='all')
# Out:
#            Record ID                         Institute  \
# count   7.020000e+02                               702
# unique           NaN                                12
# top              NaN  Brisbane North Institute of TAFE
# freq             NaN                               161
# mean    6.346026e+17                               NaN
# std     2.515071e+14                               NaN
# min     6.341330e+17                               NaN
# 25%     6.343954e+17                               NaN
# 50%     6.345835e+17                               NaN
# 75%     6.348005e+17                               NaN
# max     6.350730e+17                               NaN
#
#                         WorkArea  CESSATION YEAR  \
# count                        702      695.000000
# unique                         2             NaN
# top     Non-Delivery (corporate)             NaN
# freq                         432             NaN
# mean                         NaN     2011.423022
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
# Record ID                                                                                                                                                        702 non-null float64
# Institute                                                                                                                                                        702 non-null object
# WorkArea                                                                                                                                                         702 non-null object
# CESSATION YEAR                                                                                                                                                   695 non-null float64
# ...

# %%
tafe_survey['Contributing Factors. Career Move - Private Sector '].value_counts(dropna=False)
# Out:
# -                               336
# NaN                             265
# Career Move - Private Sector    101
# Name: Contributing Factors. Career Move - Private Sector , dtype: int64

# %% [markdown]
# ### Let's delete columns that we're not going to use for analysis so that we can make them dataframes lean af

# %%
print(dete_survey.shape)
print(tafe_survey.shape)
# Out:
# (822, 56)
# (702, 72)

# %%
dete_survey_updated = dete_survey.drop(columns=dete_survey.columns[28:49], axis=1)

# %%
tafe_survey_updated = tafe_survey.drop(columns=tafe_survey.columns[17:66], axis=1)
print(tafe_survey.shape)
print(tafe_survey_updated.shape)
# Out:
# (702, 72)
# (702, 23)

# %% [markdown]
# ### Let's clean up some of the column names to make working across datasets easier

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.replace(' ', '_').str.strip().str.lower()

# %%
tafe_survey_columns = {
    'Record ID': 'id',
    'CESSATION YEAR': 'cease_date',
    'Reason for ceasing employment': 'separationtype',
    'Gender. What is your Gender?': 'gender',
    'CurrentAge. Current Age': 'age',
    'Employment Type. Employment Type': 'employment_status',
    'Classification. Classification': 'position',
    'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
    'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service',
}
tafe_survey_updated.rename(tafe_survey_columns, axis='columns', inplace=True)

# %%
tafe_survey_updated.head(5)
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %%
dete_survey_updated.head(5)
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    role_start_date                                      position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   classification              region                      business_unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %% [markdown]
# ## Do people who have been at the company for longer leave for different reasons than people who have only been at the company for a short amount of time?
#
# Let's get everybody who has retired

# %%
tafe_survey_updated['separationtype'].value_counts(dropna=False)
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# NaN                           1
# Name: separationtype, dtype: int64

# %%
dete_survey_updated['separationtype'].value_counts(dropna=False)
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_resignations = tafe_survey_updated[tafe_survey_updated['separationtype'] == 'Resignation']
dete_resignations = dete_survey_updated[dete_survey_updated['separationtype'].str.contains('Resignation')]

# %% [markdown]
# ## Now that we have data for people who have resigned, let's verify that the dates they joined and left the company seem correct since resignation length is very important for the question we're trying to answer
#
# We shouldn't have cease dates after the current date.
#
# We also shouldn't have any start dates before 1940. If we assume that people start working in their 20s, it would make sense that people would be retiring before around the 70 mark.
#
# If there are large amounts of data that doesn't lie within these ranges, then this data is _shite_. If there's only a few rows then we can simply remove them

# %%
tafe_resignations['cease_date'].value_counts()
# Out:
# 2011.0    116
# 2012.0     94
# 2010.0     68
# 2013.0     55
# 2009.0      2
# Name: cease_date, dtype: int64

# %%
dete_resignations['cease_date'].value_counts(dropna=False)
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# NaN         11
# 11/2013      9
# 07/2013      9
# 10/2013      6
# 08/2013      4
# 05/2013      2
# 05/2012      2
# 09/2010      1
# 07/2012      1
# 07/2006      1
# 2010         1
# Name: cease_date, dtype: int64

# %%
# As some values contain the year, let's strip everything out to just be the year
dete_resignations['cease_date'].str.replace('\d{2}\/', '').value_counts(dropna=False)
# Out:
# 2013    146
# 2012    129
# 2014     22
# NaN      11
# 2010      2
# 2006      1
# Name: cease_date, dtype: int64

# %%
dete_resignations['cease_date'] = dete_resignations['cease_date'].str.replace('\d{2}\/', '').astype(float)
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dete_resignations['dete_start_date'].value_counts(dropna=False).sort_index(ascending=False)
# Out:
# 2013.0    10
# 2012.0    21
# 2011.0    24
# 2010.0    17
# 2009.0    13
# 2008.0    22
# 2007.0    21
# 2006.0    13
# 2005.0    15
# 2004.0    14
# 2003.0     6
# 2002.0     6
# 2001.0     3
# 2000.0     9
# 1999.0     8
# 1998.0     6
# 1997.0     5
# 1996.0     6
# 1995.0     4
# 1994.0     6
# 1993.0     5
# 1992.0     6
# 1991.0     4
# 1990.0     5
# 1989.0     4
# 1988.0     4
# 1987.0     1
# 1986.0     3
# 1985.0     3
# 1984.0     1
# 1983.0     2
# 1982.0     1
# 1980.0     5
# 1977.0     1
# 1976.0     2
# 1975.0     1
# 1974.0     2
# 1973.0     1
# 1972.0     1
# 1971.0     1
# 1963.0     1
# NaN       28
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations['cease_date'].value_counts(dropna=False)
# Out:
# 2011.0    116
# 2012.0     94
# 2010.0     68
# 2013.0     55
# NaN         5
# 2009.0      2
# Name: cease_date, dtype: int64

# %%
# no start date in tafe_resignations
tafe_resignations.head(5)
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
# 5       Delivery (teaching)      2010.0    Resignation
# 6  Non-Delivery (corporate)      2010.0    Resignation
# 7       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %%
tafe_resignations['cease_date'].plot(kind='box')

# %%
dete_resignations['cease_date'].plot(kind='box')

# %% [markdown]
# ## Besides the null values, the years look pretty good, son.
#
# The time span is slightly different but I don't really care
#
# Interestingly, there is no start date for the tafe dataset.

# %%
tafe_resignations.head(5)
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
# 5       Delivery (teaching)      2010.0    Resignation
# 6  Non-Delivery (corporate)      2010.0    Resignation
# 7       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %%
dete_resignations.head(5)
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
# ...

# %% [markdown]
# ## Remember we're trying to calculate years of service
#
# There is an `institute_service` column in one dataframe which has the length of service bucketed but this doesn't exist in `dete`. Let's create it

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date'] - dete_resignations['dete_start_date']
dete_resignations['institute_service'].head(5)
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 3      7.0
# 5     18.0
# 8      3.0
# 9     15.0
# 11     3.0
# Name: institute_service, dtype: float64

# %% [markdown]
# ## Let's start with just calculating people who resigned and were dissatisfied
#
# Let's not bother thinking about HOW they were dissatisfied, just whether they were dissatisfied or not.

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# NaN                                         8
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                      270
# Job Dissatisfaction     62
# NaN                      8
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %% [markdown]
# ## There are multiple columns that relate to job dissatisfaction and also there are multiple values.
#
# By changing these columns to only contain True or False, we can then create an additional column which will just contain True or False for dissatisfied

# %%
def update_vals(val):
    if val == 'NaN':
        return np.nan
    elif val == '-':
        return False
    return True

# %%
tafe_resignations[['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']] = tafe_resignations[['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']].applymap(update_vals)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
tafe_resignations['dissatisfied'] = tafe_resignations[['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']].any(axis=1, skipna=False)
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tafe_resignations['dissatisfied'].value_counts()
# Out:
# False    241
# True      99
# Name: dissatisfied, dtype: int64

# %%
dete_resignations.head(5)
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
# ...

# %%
dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction', 'dissatisfaction_with_the_department']].any(axis=1, skipna=False)
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dete_resignations['dissatisfied'].value_counts()
# Out:
# False    252
# True      59
# Name: dissatisfied, dtype: int64

# %% [markdown]
# ## As we're about to join the two datasets together, let's add a column so we can tell which original dataset the data came from

# %%
tafe_resignations['insititute'] = 'TAFE'
dete_resignations['insititute'] = 'DETE'
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dete_resignations['insititute'].value_counts()
# Out:
# DETE    311
# Name: insititute, dtype: int64

# %%
tafe_resignations['insititute'].value_counts()
# Out:
# TAFE    340
# Name: insititute, dtype: int64

# %%
combined = pd.concat([dete_resignations, tafe_resignations], ignore_index=True)
# Out:
# /Users/jlaird/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Let's drop columns that have a lot of null values. They won't be relevant for analysis

# %%
combined.notnull().sum().sort_values()
# Out:
# torres_strait                                            0
# south_sea                                                3
# aboriginal                                               7
# disability                                               8
# nesb                                                     9
# business_unit                                           32
# classification                                         161
# region                                                 265
# role_start_date                                        271
# dete_start_date                                        283
# role_service                                           290
# career_move_to_public_sector                           311
# employment_conditions                                  311
# work_location                                          311
# lack_of_job_security                                   311
# job_dissatisfaction                                    311
# ...

# %%
combined_updated = combined.dropna(thresh=500, axis=1).copy()

# %%
combined_updated.head(5)
# Out:
#      age  cease_date  dissatisfied    employment_status  gender    id  \
# 0  36-40      2012.0         False  Permanent Full-time  Female   4.0
# 1  41-45      2012.0         False  Permanent Full-time  Female   6.0
# 2  31-35      2012.0         False  Permanent Full-time  Female   9.0
# 3  46-50      2012.0          True  Permanent Part-time  Female  10.0
# 4  31-35      2012.0         False  Permanent Full-time    Male  12.0
#
#   insititute institute_service          position  \
# 0       DETE                 7           Teacher
# 1       DETE                18  Guidance Officer
# 2       DETE                 3           Teacher
# 3       DETE                15      Teacher Aide
# 4       DETE                 3           Teacher
#
#                          separationtype
# 0             Resignation-Other reasons
# 1             Resignation-Other reasons
# 2             Resignation-Other reasons
# 3            Resignation-Other employer
# 4  Resignation-Move overseas/interstate

# %% [markdown]
# ## The `institute_service` column looks to be pretty interesting
#
# However, it comes in different formats. We will want to clean this.
#
# These are the categories we want:
# * New: Less than 3 years at a company
# * Experienced: 3-6 years at a company
# * Established: 7-10 years at a company
# * Veteran: 11 or more years at a company

# %%
combined_updated['institute_service'].value_counts(dropna=False)
# Out:
# NaN                   88
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 0.0                   20
# 3.0                   20
# 6.0                   17
# 4.0                   16
# 2.0                   14
# 9.0                   14
# 7.0                   13
# More than 20 years    10
# 8.0                    8
# 13.0                   8
# 15.0                   7
# 20.0                   7
# 12.0                   6
# 22.0                   6
# 17.0                   6
# 10.0                   6
# 14.0                   6
# 18.0                   5
# 16.0                   5
# 23.0                   4
# 24.0                   4
# 11.0                   4
# 39.0                   3
# 21.0                   3
# 32.0                   3
# 19.0                   3
# 36.0                   2
# 30.0                   2
# ...

# %%
combined_updated['institute_service'].tail(20)
# Out:
# 631    Less than 1 year
# 632                 3-4
# 633                 1-2
# 634    Less than 1 year
# 635    Less than 1 year
# 636    Less than 1 year
# 637                 3-4
# 638                 1-2
# 639                 5-6
# 640                 5-6
# 641    Less than 1 year
# 642                 NaN
# 643                 3-4
# 644                 1-2
# 645                 NaN
# 646                 5-6
# 647                 1-2
# 648                 NaN
# 649                 5-6
# 650                 3-4
# Name: institute_service, dtype: object

# %%
combined_updated['institute_service'] = combined_updated['institute_service'].astype(str).str.extract('(\d+)').astype(float)
# extracting a number that appears in the string

# %%
combined_updated['institute_service'].value_counts().sort_index()
# Out:
# 0.0      20
# 1.0     159
# 2.0      14
# 3.0      83
# 4.0      16
# 5.0      56
# 6.0      17
# 7.0      34
# 8.0       8
# 9.0      14
# 10.0      6
# 11.0     30
# 12.0      6
# 13.0      8
# 14.0      6
# 15.0      7
# 16.0      5
# 17.0      6
# 18.0      5
# 19.0      3
# 20.0     17
# 21.0      3
# 22.0      6
# 23.0      4
# 24.0      4
# 25.0      2
# 26.0      2
# 27.0      1
# 28.0      2
# 29.0      1
# 30.0      2
# 31.0      1
# 32.0      3
# 33.0      1
# 34.0      1
# 35.0      1
# 36.0      2
# 38.0      1
# 39.0      3
# 41.0      1
# 42.0      1
# 49.0      1
# Name: institute_service, dtype: int64

# %%
def bucket_years_of_service(val):
    if val == pd.isnull(val):
        return np.nan
    elif val <= 3:
        return 'New'
    elif val <= 6:
        return 'Experienced'
    elif val <= 10:
        return 'Established'
    else:
        return 'Veteran'

# %%
combined_updated['service_cat'] = combined_updated['institute_service'].apply(bucket_years_of_service)

# %%
combined_updated['service_cat'].value_counts(dropna=False)
# Out:
# New            256
# Veteran        224
# Experienced     89
# Established     62
# NaN             20
# Name: service_cat, dtype: int64

# %% [markdown]
# ## Now that we have years of service and dissatisfaction, let's answer that question we had at the beginning:
#
# Do people who have been at the company for longer leave for different reasons than people who have only been at the company for a short amount of time?

# %%
combined_updated['dissatisfied'].value_counts(dropna=False)
# Out:
# False    493
# True     158
# Name: dissatisfied, dtype: int64

# %%
dis_pct = combined_updated.pivot_table(index='service_cat', values='dissatisfied')

# %%
dis_pct.plot(kind='bar')
