# %% [markdown]
# # Unemployment analysis
#
# Using FiveThirtyEight's cleaned dataset for graduate employment rates per subject. Documentation for the dataset can be found <a href="https://github.com/fivethirtyeight/data/tree/master/college-majors">on their Github</a>.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

recent_grads.rename({
    'Rank': 'rank',
    'Major_code': 'major_code',
    'Major': 'major',
    'Total': 'total',
    'Men': 'men',
    'Women': 'women',
    'Major_category': 'major_category',
    'ShareWomen': 'share_women',
    'Sample_size': 'sample_size',
    'Employed': 'employed',
    'Full_time': 'full_time',
    'Part_time': 'part_time',
    'Full_time_year_round': 'full_time_year_round',
    'Unemployed': 'unemployed',
    'Unemployment_rate': 'unemployment_rate',
    'Median': 'median',
    'P25th': 'p25th',
    'P75th': 'p75th',
    'College_jobs': 'college_jobs',
    'Non_college_jobs': 'non_college_jobs',
    'Low_wage_jobs': 'low_wage_jobs',
}, axis='columns', inplace=True)

recent_grads.iloc[0]
# Out:
# rank                                        1
# major_code                               2419
# major                   PETROLEUM ENGINEERING
# total                                    2339
# men                                      2057
# women                                     282
# major_category                    Engineering
# share_women                          0.120564
# sample_size                                36
# employed                                 1976
# full_time                                1849
# part_time                                 270
# full_time_year_round                     1207
# unemployed                                 37
# unemployment_rate                   0.0183805
# median                                 110000
# p25th                                   95000
# p75th                                  125000
# college_jobs                             1534
# non_college_jobs                          364
# ...

# %%
recent_grads.head(5)
# Out:
#    rank  major_code                                      major    total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        men    women major_category  share_women  sample_size  employed  ...  \
# 0   2057.0    282.0    Engineering     0.120564           36      1976  ...
# 1    679.0     77.0    Engineering     0.101852            7       640  ...
# 2    725.0    131.0    Engineering     0.153037            3       648  ...
# 3   1123.0    135.0    Engineering     0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering     0.341631          289     25694  ...
#
# ...

# %%
recent_grads.tail(5)
# Out:
#      rank  major_code                   major   total     men   women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                major_category  share_women  sample_size  employed  ...  \
# 168    Biology & Life Science     0.637293           47      6259  ...
# 169  Psychology & Social Work     0.817099            7      2125  ...
# 170  Psychology & Social Work     0.799859           13      2101  ...
# 171  Psychology & Social Work     0.798746           21      3777  ...
# 172                 Education     0.877960            2       742  ...
#
#      part_time  full_time_year_round  unemployed  unemployment_rate  median  \
# ...

# %%
recent_grads.describe()
# Out:
#              rank   major_code          total            men          women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        share_women  sample_size       employed      full_time      part_time  \
# count   172.000000   173.000000     173.000000     173.000000     173.000000
# mean      0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ### Let's remove any null values as graphing will fail if there are null values

# %%
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]

# %%
raw_data_count - cleaned_data_count
# Out:
# 1

# %% [markdown]
# #### Only one row contained a null value

# %% [markdown]
# ### Link between popular subjects and salary?

# %%
recent_grads.plot(x='sample_size', y='median', kind='scatter')

# %% [markdown]
# ### Link between popular subjects and unemployment?

# %%
recent_grads.plot(x='sample_size', y='unemployment_rate', kind='scatter')

# %% [markdown]
# ### Link between full time jobs and salary?

# %%
recent_grads.plot(x='full_time', y='median', kind='scatter')

# %% [markdown]
# ### Link between popular women's subjects and salary?

# %%
recent_grads.plot(x='share_women', y='unemployment_rate', kind='scatter')

# %% [markdown]
# ### Link between men and salary?

# %%
recent_grads.plot(x='men', y='median', kind='scatter')

# %% [markdown]
# ### Link between women and salary?

# %%
recent_grads.plot(x='women', y='median', kind='scatter')

# %% [markdown]
# ## Let's take a look at the distribution of columns

# %%
recent_grads['sample_size'].hist(bins=10, range=(0,4500))

# %% [markdown]
# #### A lot of the courses have a few grads

# %%
recent_grads['median'].hist(bins=20, range=(20000,80000))

# %% [markdown]
# ### The majority of grads earn between \\$30000 and \\$40000

# %%
recent_grads['employed'].hist(bins=15, range=(0,320000))

# %% [markdown]
# ### The majority of courses have mass employment. A few have mass unemployment :'(

# %%
recent_grads['full_time'].hist(bins=15, range=(0,275000))

# %% [markdown]
# ### The majority of courses have graduates employed full time

# %%
recent_grads['share_women'].hist(bins=15, range=(0,1))

# %% [markdown]
# ### Genders seem to be evenly spread among the courses

# %%
recent_grads['unemployment_rate'].hist(bins=15, range=(0,0.2))

# %% [markdown]
# ### No course has an unemployment rate of over 20%! There are a lot that has an unemployment rate floating close to 5%

# %%
recent_grads['men'].hist(bins=20, range=(0,175000))

# %%
recent_grads['women'].hist(bins=20, range=(0,320000))

# %% [markdown]
# ### There seems to be one course that has a LOT of women in it. Otherwise there is more women in a lot more courses than men. Interesting gap between 200k and 300k for women, though

# %%
# Let's get some beaut Scatter Matrices going
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['sample_size', 'median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118433d68>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['men', 'women', 'median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118e90208>,
# ...
#       dtype=object)

# %% [markdown]
# ### Seems that men have a slightly higher salary skew than women :'(

# %%
recent_grads[:10].plot.bar(x='major', y='women')

# %%
recent_grads[-10:].plot.bar(x='major', y='women')

# %%
recent_grads[-10:].plot.bar(x='major', y='unemployment_rate')

# %%
recent_grads[:10].plot.bar(x='major', y='unemployment_rate')
